# %%
 # !pip install pandas matplotlib seaborn
# Out:
# ...
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/61/11/1812ef6cbd7433ad240f72161ce5f84c4c450cede4db080365d371d29117/pandas-2.2.1-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/a1/27/8a807464b0cf47fdf3ba8cbb542d4f3a551da0254d7588667857f8a8a88a/matplotlib-3.8.3-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for seaborn from https://files.pythonhosted.org/packages/83/11/00d3c3dfc25ad54e731d91449895a79e4bf2384dc3ac01809010ba88f6d5/seaborn-0.13.2-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for numpy<2,>=1.23.2 from https://files.pythonhosted.org/packages/3f/6b/5610004206cf7f8e7ad91c5a85a8c71b2f2f8051a0c0c4d5916b76d6cbb2/numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ---------------------------------------- 61.0/61.0 kB ? eta 0:00:00
# ...

# %% [markdown]
# ### CP4 - IA -- INTEGRANTES
# 1. RM553228 RENAN BEZERRA DOS SANTOS
# 2. RM95111 LUCAS ALCANTARA CARVALHO
# 3. RM553215 KEVEN IKE PEREIRA DA SILVA

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
analise_cura = pd.read_csv('./cure_a_princesa.csv')

analise_clean_faltantes = analise_cura.dropna()

pd.set_option('display.max_rows', None)
analise_clean_faltantes

#pega a quantidade de numero de linha do dataframe
numero_linha = analise_clean_faltantes.shape[0]
print(numero_linha)
# Out:
# 795

# %%
sns.histplot(analise_clean_faltantes,
             x = "Escama de basilisco",
             hue = "Curada" 
)
# Out:
# <Axes: xlabel='Escama de basilisco', ylabel='Count'>

# %%
sns.histplot(analise_clean_faltantes,
             x = "Chifre de minotauro",
             hue = "Curada" 
)
# Out:
# <Axes: xlabel='Chifre de minotauro', ylabel='Count'>

# %%
sns.histplot(analise_clean_faltantes,
             x = "Garra de grifo",
             hue = "Curada" 
)
# Out:
# <Axes: xlabel='Garra de grifo', ylabel='Count'>

# %%
sns.histplot(analise_clean_faltantes,
             x = "Lagrimas de sereia",
             hue = "Curada" 
)
# Out:
# <Axes: xlabel='Lagrimas de sereia', ylabel='Count'>

# %%
sns.histplot(analise_clean_faltantes,
             x = "Chifre de unicornio",
             hue = "Curada" 
)
# Out:
# <Axes: xlabel='Chifre de unicornio', ylabel='Count'>

# %%
sns.histplot(analise_clean_faltantes,
             x = "Sangue de dragao",
             hue = "Curada" 
)
# Out:
# <Axes: xlabel='Sangue de dragao', ylabel='Count'>

# %%
sns.histplot(analise_clean_faltantes,
             x = "Tinta de kraken",
             hue = "Curada" 
)
# Out:
# <Axes: xlabel='Tinta de kraken', ylabel='Count'>

# %%
media = analise_clean_faltantes["Tinta de kraken"].mean()
print(media)
# Out:
# 30.384945423710324

# %%
media = analise_clean_faltantes["Chifre de unicornio"].mean()
print(media)
# Out:
# 63.00372118868696

# %%
media_dragao = analise_clean_faltantes["Sangue de dragao"].mean()
print(media_dragao)
# Out:
# 63.66174319060824

# %% [markdown]
# #Após a leitura do arquivo CSV, os ingredientes da poção foram verificados quanto a dados faltantes e duplicados. Realizamos uma análise com gráficos do Seaborn, utilizando o método histplot com hue="Curada". Os ingredientes que analisamos são os seguintes: Tinta de kraken, Chifre de unicórnio e Sangue de dragão. A média deles deve ser de 30, 63 e 63, respectivamente, para proporcionar uma cura eficaz. O elemento tóxico é a Presa de quimera, pois uma quantidade excessiva dela pode causar a morte da pessoa. Nosso argumento para esses dados é baseado na geração de gráficos e na análise comprobatória dos dados gerados pelo Seaborn.
