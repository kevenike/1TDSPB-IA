# %%
#!pip install matplotlib

# biblioteca de visualizão
import matplotlib.pyplot as plt # biblioteca de dataviz

# %%
plt.plot(
    [2, 9, 9, 2, 2], #x,
    [2, 2, 9, 9, 2 ] #y
)

# %%
plt.scatter( # scretter faz pontos
    [2, 9, 9, 2, 2], #x,
    [2, 2, 9, 9, 2 ], #y
    label ="Pontos do cubo",
    c='green',
    edgecolors='red'
)
plt.title("Titulo vem aqui")
plt.xlabel("eixo x")
plt.ylabel("eixo y")
plt.legend(loc=3, bbox_to_anchor=(1, 0.5))

# %%
plt.figure()

plt.plot( # scretter faz pontos
    [2, 9, 9, 2, 2], #x,
    [2, 2, 9, 9, 2 ], #y
    
)

plt.scatter( # scretter faz pontos
    [2, 9, 9, 2, 2], #x,
    [2, 2, 9, 9, 2 ], #y
    label ="Pontos do cubo",
    c='black',
    edgecolors='red'
)

plt.title("Titulo vem aqui")
plt.xlabel("eixo x")
plt.ylabel("eixo y")
plt.legend(loc=3, bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.savefig("quadrado.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

t = np.linspace(0, 2 * np.pi, 1024)
data2d = np.sin(t)[:, np.newaxis] * np.sqrt(t)[np.newaxis, :]

fig, ax = plt.subplots()
im = ax.imshow(data2d)
ax.set_title('Pan on the colorbar to shift the color mapping\n'
             'Zoom on the colorbar to scale the color mapping')

fig.colorbar(im, ax=ax, label='Interactive colorbar')

plt.show()

# %%
#!pip install pandas
import pandas as pd

# %%
df = pd.read_csv("gaf_esp.csv", sep=";")
display( df.sample(5) ) #head(),
# Out:
#       Espécie  Comprimento do Abdômen  Comprimento das Antenas
# 44  Gafanhoto                    2.42                     3.89
# 20  Gafanhoto                    2.40                     3.00
# 59  Esperança                    9.54                     8.76
# 15  Gafanhoto                    2.90                     1.90
# 85  Esperança                    8.69                     5.70

# %%
plt.scatter(
     df["Comprimento do Abdômen"],
     df["Comprimento das Antenas"],
)

# %%
# !pip install seaborn

import seaborn as sns

# %%
sns.scatterplot(df,
    x="Comprimento do Abdômen",
    y="Comprimento das Antenas",
    hue="Espécie"
)
# Out:
# <Axes: xlabel='Comprimento do Abdômen', ylabel='Comprimento das Antenas'>
